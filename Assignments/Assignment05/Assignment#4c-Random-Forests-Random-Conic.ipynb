# %% [markdown]
# # Assignment No 4d
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of Conic weak learner based Random Forest.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Conic')

# %%
print X.shape, Y.shape
# Out:
# (2000, 2) (2000, 1)

# %%
# %pdb
rfc.train(X,Y)
# Out:
# Automatic pdb calling has been turned ON
# Creating Left Child Node With 1010 Examples, and Right Node with 990 Examples
# Creating Left Child Node With 486 Examples, and Right Node with 524 Examples
# Creating Left Child Node With 309 Examples, and Right Node with 177 Examples
# Creating Left Child Node With 54 Examples, and Right Node with 255 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=54, classes=[(2.0, 54)]
# Creating Child Node With ClassLabel=4.0, nexamples=255, classes=[(2.0, 3), (4.0, 252)]
# Creating Left Child Node With 0 Examples, and Right Node with 177 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=177, classes=[(4.0, 177)]
# Creating Left Child Node With 27 Examples, and Right Node with 497 Examples
# Creating Left Child Node With 17 Examples, and Right Node with 10 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=17, classes=[(1.0, 3), (2.0, 2), (4.0, 12)]
# Creating Child Node With ClassLabel=4.0, nexamples=10, classes=[(4.0, 10)]
# Creating Left Child Node With 46 Examples, and Right Node with 451 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=46, classes=[(1.0, 18), (3.0, 28)]
# Creating Child Node With ClassLabel=1.0, nexamples=451, classes=[(1.0, 437), (3.0, 13), (4.0, 1)]
# Creating Left Child Node With 442 Examples, and Right Node with 548 Examples
# Creating Left Child Node With 224 Examples, and Right Node with 218 Examples
# Creating Left Child Node With 95 Examples, and Right Node with 129 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=95, classes=[(1.0, 3), (3.0, 92)]
# Creating Child Node With ClassLabel=2.0, nexamples=129, classes=[(2.0, 94), (3.0, 4), (4.0, 31)]
# Creating Left Child Node With 1 Examples, and Right Node with 217 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=217, classes=[(2.0, 217)]
# Creating Left Child Node With 144 Examples, and Right Node with 404 Examples
# Creating Left Child Node With 127 Examples, and Right Node with 17 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=127, classes=[(2.0, 127)]
# Creating Child Node With ClassLabel=4.0, nexamples=17, classes=[(4.0, 17)]
# Creating Left Child Node With 366 Examples, and Right Node with 38 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=366, classes=[(2.0, 3), (3.0, 363)]
# Creating Child Node With ClassLabel=1.0, nexamples=38, classes=[(1.0, 38)]
# Creating Left Child Node With 257 Examples, and Right Node with 1743 Examples
# Creating Left Child Node With 102 Examples, and Right Node with 155 Examples
# Creating Left Child Node With 27 Examples, and Right Node with 75 Examples
# Creating Left Child Node With 16 Examples, and Right Node with 11 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=16, classes=[(1.0, 6), (2.0, 10)]
# Creating Child Node With ClassLabel=4.0, nexamples=11, classes=[(4.0, 11)]
# Creating Left Child Node With 10 Examples, and Right Node with 65 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=10, classes=[(2.0, 9), (3.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=65, classes=[(1.0, 12), (2.0, 9), (4.0, 44)]
# Creating Left Child Node With 49 Examples, and Right Node with 106 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 41 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=8, classes=[(1.0, 8)]
# Creating Child Node With ClassLabel=4.0, nexamples=41, classes=[(1.0, 3), (4.0, 38)]
# Creating Left Child Node With 13 Examples, and Right Node with 93 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=13, classes=[(3.0, 13)]
# Creating Child Node With ClassLabel=2.0, nexamples=93, classes=[(2.0, 67), (3.0, 26)]
# Creating Left Child Node With 874 Examples, and Right Node with 869 Examples
# Creating Left Child Node With 698 Examples, and Right Node with 176 Examples
# Creating Left Child Node With 398 Examples, and Right Node with 300 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=398, classes=[(2.0, 393), (4.0, 5)]
# Creating Child Node With ClassLabel=3.0, nexamples=300, classes=[(1.0, 3), (3.0, 297)]
# Creating Left Child Node With 159 Examples, and Right Node with 17 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=159, classes=[(1.0, 1), (2.0, 4), (3.0, 154)]
# Creating Child Node With ClassLabel=3.0, nexamples=17, classes=[(1.0, 2), (2.0, 7), (3.0, 8)]
# Creating Left Child Node With 466 Examples, and Right Node with 403 Examples
# Creating Left Child Node With 466 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=466, classes=[(1.0, 465), (3.0, 1)]
# Creating Left Child Node With 22 Examples, and Right Node with 381 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=22, classes=[(2.0, 1), (4.0, 21)]
# Creating Child Node With ClassLabel=4.0, nexamples=381, classes=[(4.0, 381)]
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 36 Examples, and Right Node with 965 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 36 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 15 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=21, classes=[(2.0, 1), (3.0, 20)]
# Creating Child Node With ClassLabel=3.0, nexamples=15, classes=[(3.0, 15)]
# Creating Left Child Node With 840 Examples, and Right Node with 125 Examples
# Creating Left Child Node With 507 Examples, and Right Node with 333 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=507, classes=[(1.0, 3), (2.0, 142), (3.0, 362)]
# Creating Child Node With ClassLabel=2.0, nexamples=333, classes=[(2.0, 316), (3.0, 17)]
# Creating Left Child Node With 57 Examples, and Right Node with 68 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=57, classes=[(2.0, 21), (3.0, 36)]
# Creating Child Node With ClassLabel=3.0, nexamples=68, classes=[(2.0, 18), (3.0, 50)]
# Creating Left Child Node With 368 Examples, and Right Node with 631 Examples
# Creating Left Child Node With 367 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 359 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=8, classes=[(2.0, 1), (4.0, 7)]
# Creating Child Node With ClassLabel=4.0, nexamples=359, classes=[(4.0, 359)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Left Child Node With 341 Examples, and Right Node with 290 Examples
# Creating Left Child Node With 66 Examples, and Right Node with 275 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=66, classes=[(1.0, 65), (4.0, 1)]
# Creating Child Node With ClassLabel=1.0, nexamples=275, classes=[(1.0, 265), (4.0, 10)]
# Creating Left Child Node With 123 Examples, and Right Node with 167 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=123, classes=[(4.0, 123)]
# Creating Child Node With ClassLabel=1.0, nexamples=167, classes=[(1.0, 167)]
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 493 Examples, and Right Node with 508 Examples
# Creating Left Child Node With 302 Examples, and Right Node with 191 Examples
# Creating Left Child Node With 294 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=294, classes=[(3.0, 294)]
# Creating Child Node With ClassLabel=3.0, nexamples=8, classes=[(3.0, 8)]
# Creating Left Child Node With 112 Examples, and Right Node with 79 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=112, classes=[(2.0, 112)]
# Creating Child Node With ClassLabel=3.0, nexamples=79, classes=[(2.0, 1), (3.0, 78)]
# Creating Left Child Node With 115 Examples, and Right Node with 393 Examples
# Creating Left Child Node With 20 Examples, and Right Node with 95 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=20, classes=[(1.0, 2), (3.0, 18)]
# Creating Child Node With ClassLabel=3.0, nexamples=95, classes=[(3.0, 95)]
# Creating Left Child Node With 73 Examples, and Right Node with 320 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=73, classes=[(1.0, 1), (2.0, 68), (3.0, 4)]
# Creating Child Node With ClassLabel=2.0, nexamples=320, classes=[(2.0, 317), (3.0, 3)]
# Creating Left Child Node With 575 Examples, and Right Node with 424 Examples
# Creating Left Child Node With 460 Examples, and Right Node with 115 Examples
# Creating Left Child Node With 303 Examples, and Right Node with 157 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=303, classes=[(1.0, 67), (2.0, 1), (4.0, 235)]
# Creating Child Node With ClassLabel=4.0, nexamples=157, classes=[(1.0, 5), (4.0, 152)]
# Creating Left Child Node With 3 Examples, and Right Node with 112 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=3, classes=[(1.0, 3)]
# Creating Child Node With ClassLabel=4.0, nexamples=112, classes=[(4.0, 112)]
# Creating Left Child Node With 6 Examples, and Right Node with 418 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=3, classes=[(1.0, 3)]
# Creating Child Node With ClassLabel=1.0, nexamples=3, classes=[(1.0, 1), (2.0, 1), (4.0, 1)]
# Creating Left Child Node With 0 Examples, and Right Node with 418 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=418, classes=[(1.0, 418)]
# Creating Left Child Node With 638 Examples, and Right Node with 1362 Examples
# Creating Left Child Node With 260 Examples, and Right Node with 378 Examples
# Creating Left Child Node With 93 Examples, and Right Node with 167 Examples
# Creating Left Child Node With 16 Examples, and Right Node with 77 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=16, classes=[(1.0, 9), (4.0, 7)]
# Creating Child Node With ClassLabel=4.0, nexamples=77, classes=[(1.0, 4), (4.0, 73)]
# Creating Left Child Node With 64 Examples, and Right Node with 103 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=64, classes=[(1.0, 1), (4.0, 63)]
# Creating Child Node With ClassLabel=4.0, nexamples=103, classes=[(4.0, 103)]
# Creating Left Child Node With 0 Examples, and Right Node with 378 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 367 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=11, classes=[(1.0, 11)]
# Creating Child Node With ClassLabel=1.0, nexamples=367, classes=[(1.0, 367)]
# Creating Left Child Node With 685 Examples, and Right Node with 677 Examples
# Creating Left Child Node With 156 Examples, and Right Node with 529 Examples
# Creating Left Child Node With 56 Examples, and Right Node with 100 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=56, classes=[(2.0, 56)]
# Creating Child Node With ClassLabel=2.0, nexamples=100, classes=[(2.0, 55), (3.0, 45)]
# Creating Left Child Node With 14 Examples, and Right Node with 515 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=14, classes=[(4.0, 14)]
# Creating Child Node With ClassLabel=3.0, nexamples=515, classes=[(2.0, 220), (3.0, 295)]
# Creating Left Child Node With 267 Examples, and Right Node with 410 Examples
# Creating Left Child Node With 69 Examples, and Right Node with 198 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=69, classes=[(1.0, 61), (3.0, 8)]
# Creating Child Node With ClassLabel=3.0, nexamples=198, classes=[(1.0, 47), (3.0, 151)]
# Creating Left Child Node With 389 Examples, and Right Node with 21 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=389, classes=[(2.0, 156), (4.0, 233)]
# Creating Child Node With ClassLabel=2.0, nexamples=21, classes=[(2.0, 13), (3.0, 1), (4.0, 7)]
# Creating Left Child Node With 1094 Examples, and Right Node with 906 Examples
# Creating Left Child Node With 432 Examples, and Right Node with 662 Examples
# Creating Left Child Node With 149 Examples, and Right Node with 283 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 149 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=149, classes=[(1.0, 149)]
# Creating Left Child Node With 101 Examples, and Right Node with 182 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=101, classes=[(1.0, 101)]
# Creating Child Node With ClassLabel=1.0, nexamples=182, classes=[(1.0, 167), (3.0, 15)]
# Creating Left Child Node With 12 Examples, and Right Node with 650 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 7)]
# Creating Child Node With ClassLabel=2.0, nexamples=5, classes=[(2.0, 3), (4.0, 2)]
# Creating Left Child Node With 122 Examples, and Right Node with 528 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=122, classes=[(2.0, 95), (3.0, 27)]
# Creating Child Node With ClassLabel=3.0, nexamples=528, classes=[(1.0, 26), (3.0, 401), (4.0, 101)]
# Creating Left Child Node With 849 Examples, and Right Node with 57 Examples
# Creating Left Child Node With 392 Examples, and Right Node with 457 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 391 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=391, classes=[(4.0, 391)]
# Creating Left Child Node With 59 Examples, and Right Node with 398 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=59, classes=[(2.0, 2), (3.0, 57)]
# Creating Child Node With ClassLabel=2.0, nexamples=398, classes=[(2.0, 392), (4.0, 6)]
# Creating Left Child Node With 0 Examples, and Right Node with 57 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 57 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=57, classes=[(1.0, 57)]
# Creating Left Child Node With 496 Examples, and Right Node with 1504 Examples
# Creating Left Child Node With 181 Examples, and Right Node with 315 Examples
# Creating Left Child Node With 30 Examples, and Right Node with 151 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 30 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=30, classes=[(2.0, 30)]
# Creating Left Child Node With 9 Examples, and Right Node with 142 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=9, classes=[(2.0, 8), (3.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=142, classes=[(2.0, 142)]
# Creating Left Child Node With 278 Examples, and Right Node with 37 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 278 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=278, classes=[(2.0, 278)]
# Creating Left Child Node With 0 Examples, and Right Node with 37 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=37, classes=[(2.0, 35), (4.0, 2)]
# Creating Left Child Node With 723 Examples, and Right Node with 781 Examples
# Creating Left Child Node With 566 Examples, and Right Node with 157 Examples
# Creating Left Child Node With 349 Examples, and Right Node with 217 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=349, classes=[(1.0, 347), (4.0, 2)]
# Creating Child Node With ClassLabel=3.0, nexamples=217, classes=[(1.0, 4), (3.0, 213)]
# Creating Left Child Node With 140 Examples, and Right Node with 17 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=140, classes=[(3.0, 140)]
# Creating Child Node With ClassLabel=3.0, nexamples=17, classes=[(1.0, 5), (3.0, 12)]
# Creating Left Child Node With 276 Examples, and Right Node with 505 Examples
# Creating Left Child Node With 136 Examples, and Right Node with 140 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=136, classes=[(1.0, 67), (3.0, 69)]
# Creating Child Node With ClassLabel=1.0, nexamples=140, classes=[(1.0, 75), (3.0, 65)]
# Creating Left Child Node With 216 Examples, and Right Node with 289 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=216, classes=[(1.0, 2), (2.0, 7), (4.0, 207)]
# Creating Child Node With ClassLabel=4.0, nexamples=289, classes=[(4.0, 289)]
# Creating Left Child Node With 1131 Examples, and Right Node with 869 Examples
# Creating Left Child Node With 989 Examples, and Right Node with 142 Examples
# Creating Left Child Node With 444 Examples, and Right Node with 545 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 433 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=11, classes=[(1.0, 11)]
# Creating Child Node With ClassLabel=4.0, nexamples=433, classes=[(1.0, 4), (4.0, 429)]
# Creating Left Child Node With 87 Examples, and Right Node with 458 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=87, classes=[(1.0, 20), (4.0, 67)]
# Creating Child Node With ClassLabel=1.0, nexamples=458, classes=[(1.0, 458)]
# Creating Left Child Node With 73 Examples, and Right Node with 69 Examples
# Creating Left Child Node With 20 Examples, and Right Node with 53 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=20, classes=[(2.0, 17), (4.0, 3)]
# Creating Child Node With ClassLabel=2.0, nexamples=53, classes=[(2.0, 52), (4.0, 1)]
# Creating Left Child Node With 5 Examples, and Right Node with 64 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=5, classes=[(1.0, 5)]
# Creating Child Node With ClassLabel=3.0, nexamples=64, classes=[(1.0, 2), (2.0, 3), (3.0, 59)]
# Creating Left Child Node With 453 Examples, and Right Node with 416 Examples
# Creating Left Child Node With 420 Examples, and Right Node with 33 Examples
# Creating Left Child Node With 17 Examples, and Right Node with 403 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=17, classes=[(3.0, 17)]
# Creating Child Node With ClassLabel=3.0, nexamples=403, classes=[(3.0, 403)]
# Creating Left Child Node With 8 Examples, and Right Node with 25 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=8, classes=[(2.0, 7), (3.0, 1)]
# Creating Child Node With ClassLabel=3.0, nexamples=25, classes=[(2.0, 12), (3.0, 13)]
# Creating Left Child Node With 409 Examples, and Right Node with 7 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 409 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=409, classes=[(2.0, 409)]
# Creating Left Child Node With 5 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=5, classes=[(3.0, 5)]
# Creating Child Node With ClassLabel=3.0, nexamples=2, classes=[(3.0, 2)]
# Creating Left Child Node With 765 Examples, and Right Node with 1235 Examples
# Creating Left Child Node With 579 Examples, and Right Node with 186 Examples
# Creating Left Child Node With 121 Examples, and Right Node with 458 Examples
# Creating Left Child Node With 19 Examples, and Right Node with 102 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=19, classes=[(1.0, 12), (3.0, 7)]
# Creating Child Node With ClassLabel=1.0, nexamples=102, classes=[(1.0, 102)]
# Creating Left Child Node With 40 Examples, and Right Node with 418 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=40, classes=[(3.0, 40)]
# Creating Child Node With ClassLabel=3.0, nexamples=418, classes=[(3.0, 418)]
# Creating Left Child Node With 44 Examples, and Right Node with 142 Examples
# Creating Left Child Node With 18 Examples, and Right Node with 26 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=18, classes=[(1.0, 2), (2.0, 5), (3.0, 4), (4.0, 7)]
# Creating Child Node With ClassLabel=4.0, nexamples=26, classes=[(1.0, 1), (2.0, 1), (4.0, 24)]
# Creating Left Child Node With 14 Examples, and Right Node with 128 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=14, classes=[(3.0, 14)]
# Creating Child Node With ClassLabel=1.0, nexamples=128, classes=[(1.0, 116), (3.0, 11), (4.0, 1)]
# Creating Left Child Node With 828 Examples, and Right Node with 407 Examples
# Creating Left Child Node With 473 Examples, and Right Node with 355 Examples
# Creating Left Child Node With 327 Examples, and Right Node with 146 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=327, classes=[(2.0, 68), (4.0, 259)]
# Creating Child Node With ClassLabel=4.0, nexamples=146, classes=[(2.0, 71), (3.0, 1), (4.0, 74)]
# Creating Left Child Node With 0 Examples, and Right Node with 355 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=355, classes=[(2.0, 355)]
# Creating Left Child Node With 24 Examples, and Right Node with 383 Examples
# Creating Left Child Node With 15 Examples, and Right Node with 9 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=15, classes=[(1.0, 10), (3.0, 5)]
# Creating Child Node With ClassLabel=4.0, nexamples=9, classes=[(4.0, 9)]
# Creating Left Child Node With 104 Examples, and Right Node with 279 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=104, classes=[(1.0, 6), (4.0, 98)]
# Creating Child Node With ClassLabel=1.0, nexamples=279, classes=[(1.0, 251), (4.0, 28)]
# Creating Left Child Node With 719 Examples, and Right Node with 1281 Examples
# Creating Left Child Node With 72 Examples, and Right Node with 647 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 49 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 23 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=23, classes=[(1.0, 18), (3.0, 5)]
# Creating Left Child Node With 0 Examples, and Right Node with 49 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=49, classes=[(2.0, 28), (4.0, 21)]
# Creating Left Child Node With 142 Examples, and Right Node with 505 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 142 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=142, classes=[(3.0, 142)]
# Creating Left Child Node With 447 Examples, and Right Node with 58 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=447, classes=[(2.0, 447)]
# Creating Child Node With ClassLabel=3.0, nexamples=58, classes=[(2.0, 8), (3.0, 50)]
# Creating Left Child Node With 955 Examples, and Right Node with 326 Examples
# Creating Left Child Node With 517 Examples, and Right Node with 438 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 515 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=2, classes=[(4.0, 2)]
# Creating Child Node With ClassLabel=4.0, nexamples=515, classes=[(1.0, 92), (4.0, 423)]
# Creating Left Child Node With 24 Examples, and Right Node with 414 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=24, classes=[(1.0, 24)]
# Creating Child Node With ClassLabel=1.0, nexamples=414, classes=[(1.0, 361), (4.0, 53)]
# Creating Left Child Node With 14 Examples, and Right Node with 312 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=10, classes=[(1.0, 5), (3.0, 5)]
# Creating Child Node With ClassLabel=2.0, nexamples=4, classes=[(2.0, 3), (4.0, 1)]
# Creating Left Child Node With 307 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=307, classes=[(2.0, 10), (3.0, 297)]
# Creating Child Node With ClassLabel=2.0, nexamples=5, classes=[(2.0, 4), (3.0, 1)]

# %%
len(rfc.trees)
# Out:
# 10

# %%
# %pdb
# Training Confusion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# Automatic pdb calling has been turned OFF
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        494    0    2    4   500
# 2.0          0  499    0    1   500
# 3.0          3    2  495    0   500
# 4.0          1    0    0  499   500
# All        498  501  497  504  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        247    0    0    3   250
# 2.0          0  249    0    1   250
# 3.0          1    1  248    0   250
# 4.0          0    1    0  249   250
# All        248  251  248  253  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
import tools as t

# %%
t.plot_points_range(rfc,X,Y,10000)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows=ntrees/2 + 1
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout()

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print X.shape, Y.shape

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Conic',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)

# %% [markdown]
# ###Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows=ntrees/2 + 1
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
