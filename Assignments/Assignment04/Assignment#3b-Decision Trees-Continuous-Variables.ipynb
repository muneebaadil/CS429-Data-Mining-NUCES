# %% [markdown]
# # Assignment No 3a
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement a Decision Tree Classifier.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %% [markdown]
# ### Decision Tree Classifier
#
# Now in this assignment we will be implementing the Decision Classifier for both Continuous and Categorical attributes.
#
# You will be testing your implementations with three different split criterias, namely:
#  - Information Gain
#  - Gini Index
#  - CART

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class Node:
    def __init__(self,purity,klasslabel='',score=0,split=[],fidx=-1):
        self.lchild=None       
        self.rchild=None
        self.klasslabel=klasslabel        
        self.split=split
        self.score=score
        self.fidx=fidx
        self.purity=purity
        
    def set_childs(self,lchild,rchild):
        # YOUR CODE HERE
        self.lchild = lchild 
        self.rchild = rchild 
        #raise NotImplementedError()
    def isleaf(self):
        # YOUR CODE HERE
        return (self.lchild is None) and (self.rchild is None)
        #raise NotImplementedError()
    def isless_than_eq(self, X):
        # YOUR CODE HERE
        leftidx = np.nonzero(X[:, fidx] <= self.split)
        rightidx = np.nonzero(X[:, fidx] > self.split)
        return X[leftidx, :], X[rightidx, :]
        #raise NotImplementedError()
    def get_str(self):        
        if self.isleaf():
            return 'C(class={},Purity={})'.format(self.klasslabel,self.purity)
        else:
            return 'I(Fidx={},Score={},Split={})'.format(self.fidx,self.score,self.split)

# %%
# A placeholder class 
# TODO: You have to implement the following class, remember from the lectures that you will 
# need to build a model for each different class you are trying to identify...

# %%
import pdb
## Your code goes here...
# You might need to define auxliary classes for composition.. ?
class DecisionTree:
    ''' Implements the Decision Tree For Classification... '''
    def __init__(self, purityp, exthreshold,maxdepth=10):        
        self.purity=purityp
        self.exthreshold=exthreshold
        self.maxdepth=maxdepth
        pass
    
    def generateCounts(self, labels):
        out = np.unique(labels, return_counts=True)
        return out[1] 
    
    def calculateEntropy(self, D):
        Dprobs = D / (1. * np.sum(D))+1e-16
        out = np.sum(Dprobs * np.log(Dprobs)) * -1
        return out
    
    def calculateSplitEntropy(self, Dy, Dn):
        nexamples = (np.sum(Dy)+np.sum(Dn)) * 1.
        a = (np.sum(Dy)/nexamples)*(self.calculateEntropy(Dy))
        b = (np.sum(Dn)/nexamples)*(self.calculateEntropy(Dn))
        return a+b
    
    def getPurityResult(self, Y):
        classes, counts = np.unique(Y, return_counts=True)
        probs = counts/(1.*np.sum(counts))
        return probs.max(), classes[probs.argmax()]
    
    def train(self, X, Y):
        ''' Train Decision Tree using the given 
            X [m x d] data matrix and Y labels matrix
            
            Input:
            ------
            X: [m x d] a data matrix of m d-dimensional examples.
            Y: [m x 1] a label vector.
            
            Returns:
            -----------
            Nothing
            '''
        nexamples,nfeatures=X.shape
        ## now go and train a model for each class...
        # YOUR CODE HERE
        self.classes = np.unique(Y)
        self.tree = self.build_tree(X, Y, self.maxdepth)
        #raise NotImplementedError()
        
    def build_tree(self, X, Y, depth):
        """ 
            Function is used to recursively build the decision Tree 
          
            Input
            -----
            X: [m x d] a data matrix of m d-dimensional examples.
            Y: [m x 1] a label vector.
            
            Returns
            -------
            root node of the built tree...
        """
        nexamples, nfeatures=X.shape
      
        klasses=np.unique(Y);
        # YOUR CODE HERE
        purityres = self.getPurityResult(Y)
        if (depth == 0) or (X.shape[0] < self.exthreshold) or (purityres[0] > self.purity):
            node = Node(purityres[0],klasslabel=purityres[1])
        else: 
            featscores = np.zeros((X.shape[1],))
            for fidx in xrange(X.shape[1]):
                v, score, Xlidx, Xridx = self.evaluate_numerical_attribute(X[:, fidx], Y)
                featscores[fidx] = score
                
            threshold, splitscore, lidx, ridx = self.evaluate_numerical_attribute(X[:, featscores.argmin()], Y)
            
            lchild = self.build_tree(X[lidx], Y[lidx], depth-1)
            rchild = self.build_tree(X[ridx], Y[ridx], depth-1)
            
            node = Node(purity=purityres[0],score=splitscore, fidx=featscores.argmin(),split=threshold)
            node.set_childs(lchild, rchild)
        #raise NotImplementedError()
        return node
        
    def test(self, X):
        
        ''' Test the trained classifiers on the given set of examples 
        
                   
            Input:
            ------
            X: [m x d] a data matrix of m d-dimensional test examples.
           
            Returns:
            -----------
                pclass: the predicted class for each example, i.e. to which it belongs
        '''
        
        nexamples, nfeatures=X.shape
        pclasses=self.predict(X)
        
        # your code go here...
        
        return np.array(pclasses)
    
    def evaluate_numerical_attribute(self,feat, Y):
        '''
            Evaluates the numerical attribute for all possible split points for
            possible feature selection
            
            Input:
            ---------
            feat: a contiuous feature
            Y: labels
            
            Returns:
            ----------
            v: splitting threshold
            score: splitting score
            Xlidx: Index of examples belonging to left child node
            Xridx: Index of examples belonging to right child node
            
        '''
        
        # A big source of Bugs will be sorting the same array and expecting it to behave original,
        # use separate variables to store the sorted array and its corresponding classes labels...
        
        classes=np.unique(Y)
        nclasses=len(self.classes)
        sidx=np.argsort(feat)
        f=feat[sidx] # sorted features
        sY=Y[sidx] # sorted features class labels...
        
        # YOUR CODE HERE
        #raise NotImplementedError()
        #YclassCounts = self.generateCounts(Y, nclasses)
        
        points = np.sort(np.unique(feat)) 
        midpoints = (points[:-1]+points[1:]) / 2.
        splitscores = np.zeros((midpoints.shape[0],))
        
        for i, splitpoint in enumerate(midpoints):
            DyClassCounts = self.generateCounts(Y[feat <= splitpoint])
            DnClassCounts = self.generateCounts(Y[feat > splitpoint])
            splitscores[i] = self.calculateSplitEntropy(DyClassCounts, DnClassCounts)
            
        v = midpoints[splitscores.argmin()]
        score = splitscores.min()
        Xlidx = np.nonzero(feat <= v)
        Xridx = np.nonzero(feat > v)
        
        return v, score, Xlidx, Xridx
    
    def predict(self, X):
        
        """
        Test the trained classifiers on the given example X
        
                   
            Input:
            ------
            X: [1 x d] a d-dimensional test example.
           
            Returns:
            -----------
                pclass: the predicted class for the given example, i.e. to which it belongs
        """
        z=[]
        
        for idx in range(X.shape[0]):
            
            z.append(self._predict(self.tree,X[idx,:]))
        
        return z 
    
    def _predict(self,node, X):
        # YOUR CODE HERE
        if node.isleaf(): 
            return node.klasslabel
        else:
            return self._predict(node.lchild, X) if (X[node.fidx] <= node.split) else self._predict(node.rchild, X)
        #raise NotImplementedError()

    def __str__(self):
        
        return self.__print(self.tree)        
        
     
    def find_depth(self):
        return self._find_depth(self.tree)
    
    
    def _find_depth(self,node):
        if not node:
            return
        if node.isleaf():
            return 1
        else:
            return max(self._find_depth(node.lchild),self._find_depth(node.rchild))+1
    def __print(self,node,depth=0):
        
        ret = ""

        # Print right branch
        if node.rchild:
            ret += self.__print(node.rchild,depth+1)

        # Print own value
        
        ret += "\n" + ("    "*depth) + node.get_str()

        # Print left branch
        if node.lchild:
            ret += self.__print(node.lchild,depth+1)
        
        return ret

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..

# %%
#load the data set
data=pd.read_csv('./iris.data')
data.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
print data.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   149.000000  149.000000   149.000000  149.000000
# mean      5.848322    3.051007     3.774497    1.205369
# std       0.828594    0.433499     1.759651    0.761292
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
# Get your data in matrix
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())
print " Data Set Dimensions=", X.shape, " True Class labels dimensions", Y.shape
# Out:
#  Data Set Dimensions= (149, 4)  True Class labels dimensions (149,)

# %%
print Y
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %%
Y[Y=='Iris-virginica']='Iris-versicolor'
print Y, len(Y), np.unique(Y)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'] 149 ['Iris-setosa' 'Iris-versicolor']

# %% [markdown]
# ### Debugging Tip
# You can import pdb and call its function set_trace (i.e pdb.set_trace()) any where in your code to stop the execution of your code and inspect it line by line by using pdf. Otherwise, you can use Pycharm GUI debugger.

# %%
# import pdb 
# pdb.set_trace()

# %%
np.sum((X[:,0]<=5.45) & (Y=='Iris-versicolor'))
# Out:
# 7

# %%
print ['{:0.5}'.format(p) for p in X[:,0]]
# Out:
# ['4.9', '4.7', '4.6', '5.0', '5.4', '4.6', '5.0', '4.4', '4.9', '5.4', '4.8', '4.8', '4.3', '5.8', '5.7', '5.4', '5.1', '5.7', '5.1', '5.4', '5.1', '4.6', '5.1', '4.8', '5.0', '5.0', '5.2', '5.2', '4.7', '4.8', '5.4', '5.2', '5.5', '4.9', '5.0', '5.5', '4.9', '4.4', '5.1', '5.0', '4.5', '4.4', '5.0', '5.1', '4.8', '5.1', '4.6', '5.3', '5.0', '7.0', '6.4', '6.9', '5.5', '6.5', '5.7', '6.3', '4.9', '6.6', '5.2', '5.0', '5.9', '6.0', '6.1', '5.6', '6.7', '5.6', '5.8', '6.2', '5.6', '5.9', '6.1', '6.3', '6.1', '6.4', '6.6', '6.8', '6.7', '6.0', '5.7', '5.5', '5.5', '5.8', '6.0', '5.4', '6.0', '6.7', '6.3', '5.6', '5.5', '5.5', '6.1', '5.8', '5.0', '5.6', '5.7', '5.7', '6.2', '5.1', '5.7', '6.3', '5.8', '7.1', '6.3', '6.5', '7.6', '4.9', '7.3', '6.7', '7.2', '6.5', '6.4', '6.8', '5.7', '5.8', '6.4', '6.5', '7.7', '7.7', '6.0', '6.9', '5.6', '7.7', '6.3', '6.7', '7.2', '6.2', '6.1', '6.4', '7.2', '7.4', '7.9', '6.4', '6.3', '6.1', '7.7', '6.3', '6.4', '6.0', '6.9', '6.7', '6.9', '5.8', '6.8', '6.7', '6.7', '6.3', '6.5', '6.2', '5.9']

# %%
print len(Y)
feat=[0,1]
dt=DecisionTree(0.95,5,2)
feat=[0,1]
dt.classes=np.unique(Y)
dt.nclasses=len(np.unique(Y))
split,mingain,Xlidx,Xridx=dt.evaluate_numerical_attribute(X[:,0],Y)

# You should get following result:, see the example on book page 490-491, Data Mining and Analysis...
# Split=5.45, H(DY)=0.577004250316,P(DY)=0.342281879195,H(DN)=0.290715865467,P(DN)=0.657718120805,gain=0.388707191825
# Out:
# 149

# %%
dt.classes=np.unique(Y)
dt.nclasses=len(np.unique(Y))
split,mingain,Xlidx,Xridx=dt.evaluate_numerical_attribute(X[:,0],Y)

# %%
from nose.tools import assert_almost_equal, assert_equal

assert_equal(split, 5.45)
assert_almost_equal(mingain, 0.38, places=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-446a4f37b4a1> in <module>()
#       2
#       3 assert_equal(split, 5.45)
# ----> 4 assert_almost_equal(mingain, 0.38, places=1)
#
# /home/muneebaadil/anaconda2/lib/python2.7/unittest/case.pyc in assertAlmostEqual(self, first, second, places, msg, delta)
#     559                                                           places)
#     560         msg = self._formatMessage(msg, standardMsg)
# --> 561         raise self.failureException(msg)
#     562
#     563     def assertNotAlmostEqual(self, first, second, places=None, msg=None, delta=None):
#
# AssertionError: 0.26943129407679656 != 0.38 within 1 places

# %%
Y[Y=='Iris-virginica']='Iris-versicolor'
print len(Y)
feat=[2,3]
dt=DecisionTree(0.95,5)
dt.train(X[:,feat],Y)
# g,s,xl,xr=dt.evaluate_numerical_attribute(X[:,2],Y)
#print g, s, xl, xr
# Out:
# 149

# %%
print dt
# Out:
#     C(class=Iris-versicolor,Purity=1.0)
# I(Fidx=0,Score=1.87890943588e-15,Split=2.45)
#     C(class=Iris-setosa,Purity=1.0)

# %%
print dt.find_depth()
# Out:
# 2

# %%
# %pdb
print " Plotting the Decision Surface of Training Set... "
t.plot_decision_regions(X[:,feat],Y,clf=dt, res=0.1, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Training Set...

# %%
# Split your data into training and test-set... 
# see the documentation of split_data in tools for further information...
Xtrain,Ytrain,Xtest,Ytest=t.split_data(X,Y)

print " Training Data Set Dimensions=", Xtrain.shape, "Training True Class labels dimensions", Ytrain.shape   
print " Test Data Set Dimensions=", Xtest.shape, "Test True Class labels dimensions", Ytrain.shape
# Out:
#  Training Data Set Dimensions= (104, 4) Training True Class labels dimensions (104,)
#  Test Data Set Dimensions= (45, 4) Test True Class labels dimensions (104,)

# %%
# Lets train a Decision Tree Classifier on Petal Length and Width
feat=[0,1]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)

# %%
#Lets test it on the set of unseen examples...
pclasses=dt.predict(Xtest[:,feat])

# %%
print pclasses
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']

# %% [markdown]
# Lets see how good we are doing...
# ==================

# %%
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 42
# Accuracy =  0.933333333333

# %%
#Lets plot the decision surface
print " Plotting the Decision Surface of Training Set... "
t.plot_decision_regions(Xtrain[:,feat],Ytrain,clf=dt, res=0.02, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Training Set...

# %%
print " Plotting the Decision Surface of Test Set... "
t.plot_decision_regions(Xtest[:,feat],Ytest,clf=dt, res=0.02, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Test Set...

# %%
from nose.tools import assert_greater_equal
feat=[0,1]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
acc = np.sum(pclasses==Ytest)/float(Ytest.shape[0])
assert_greater_equal(acc, 0.90)

# %% [markdown]
# # Lets Train on all four features....

# %%
#Lets Train on all four features....

# Lets train a Decision Tree Classifier on Petal Length and Width
feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 45
# Accuracy =  1.0

# %% [markdown]
# # Lets Train on all four features and for all three classes....

# %%
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())
print " Data Set Dimensions=", X.shape, " True Class labels dimensions", Y.shape
# Out:
#  Data Set Dimensions= (149, 4)  True Class labels dimensions (149,)

# %%
# Split your data into training and test-set... 
# see the documentation of split_data in tools for further information...
Xtrain,Ytrain,Xtest,Ytest=t.split_data(X,Y)

print " Training Data Set Dimensions=", Xtrain.shape, "Training True Class labels dimensions", Ytrain.shape   
print " Test Data Set Dimensions=", Xtest.shape, "Test True Class labels dimensions", Ytrain.shape
# Out:
#  Training Data Set Dimensions= (104, 4) Training True Class labels dimensions (104,)
#  Test Data Set Dimensions= (45, 4) Test True Class labels dimensions (104,)

# %%
feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 43
# Accuracy =  0.955555555556

# %%
from nose.tools import assert_greater_equal

feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
acc = np.sum(pclasses==Ytest)/float(Ytest.shape[0])
assert_greater_equal(acc, 0.90)

# %% [markdown]
# What can you conclude ?
# ====================
# Please write your observation....

# %% [markdown]
# # Cross-Validation
#
# Until now we have been splitting the dataset into a training and test set rather randomly and were reporting a rather artifical performance. Now we are going to test our system exhaustively by making use of k-fold [cross validation](http://en.wikipedia.org/wiki/Cross-validation_%28statistics%29).
#
# Now go and tune your hyper-parameters (purity, exthreshold) to opitmize the performance.

# %%
# Now lets cross validate for best paramters, and test the result...
# We will be training four different models on four different partitions of data set and 
# then will be reporting the mean accuracy of the four classifiers.

nfolds=4 # lets use four folds..
folds=t.generate_folds(X,Y,nfolds)
features=[0,1, 2, 3] # features to use for our system
#now lets train and test on these folds...

#Lets perform the grid search...
purity=np.linspace(0.85,0.97,13) # You can also search over depth as well....
nexamp=np.linspace(5,25,21)  

params=np.zeros((len(purity),len(nexamp)))
                   
for p in range(len(purity)):
    for n in range(len(nexamp)):
        totacc=[]
        for k in range(nfolds):
            dt=DecisionTree(purity[p],nexamp[n])
            dt.train(folds[k][0][:,features],folds[k][1])
            pclasses=dt.predict(folds[k][2][:,features])
            acc=np.sum(pclasses==folds[k][3])/float(folds[k][3].shape[0])
            print "[Info] Fold {} Accuracy = {}".format(k+1, acc)
            totacc.append(acc)
        params[p,n]=np.mean(totacc)
        print totacc, '\nPurity={}, Nexample-threshold={}, Mean Accuracy ={}'.format(purity[p],nexamp[n], np.mean(totacc))
# Out:
# Generating CV data for 3 classes
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.85, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.86, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.87, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.88, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.89, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=5.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=6.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=7.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=8.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=9.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=10.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=11.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.9, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=5.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=6.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=7.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=8.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=9.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=10.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.91, Nexample-threshold=11.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.91, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=5.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=6.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=7.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=8.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=9.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=10.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.92, Nexample-threshold=11.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.92, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# ...
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.95, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=5.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=6.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=7.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=8.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=9.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=10.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.96, Nexample-threshold=11.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.96, Nexample-threshold=25.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=5.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=6.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=7.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=8.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=9.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=10.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.972222222222
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.97222222222222221]
# Purity=0.97, Nexample-threshold=11.0, Mean Accuracy =0.951388888889
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=12.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=13.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=14.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=15.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=16.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=17.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=18.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=19.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=20.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=21.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=22.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=23.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=24.0, Mean Accuracy =0.944444444444
# [Info] Fold 1 Accuracy = 1.0
# [Info] Fold 2 Accuracy = 0.888888888889
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# [1.0, 0.88888888888888884, 0.94444444444444442, 0.94444444444444442]
# Purity=0.97, Nexample-threshold=25.0, Mean Accuracy =0.944444444444

# %%
np.save('dt-cv',params)

# %%
print params
# Out:
# [[ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.95138889  0.95138889  0.95138889  0.95138889  0.95138889  0.95138889
#    0.95138889  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]]

# %%
print params.shape
# Out:
# (13, 21)

# %%
plt.imshow(params) # displayc the accuracy as 2D image...

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
tX, tY = np.meshgrid(purity, nexamp)
ax.plot_surface(tX,tY,params.T)
ax.set_xlabel('Purity')
ax.set_ylabel('Nexamples')
ax.set_zlabel('Mean Accuracy across {}-Folds'.format(nfolds))
# ax.scatter3D(data['SepalLength'],data['PetalLength'],data['PetalWidth'])
#(params,ax,'Purity','Example-Threshold','Mean-Accuracy')

# %%
print params.shape, tX.shape, tY.shape
# Out:
# (13, 21) (21, 13) (21, 13)

# %%
#print the row and column  index of m
#single line code
ridx,cidx= np.unravel_index(np.argmax(params), params.shape)

# simple step-wise code

cidx=np.argmax(params.max(axis=0))
ridx=np.argmax(params[:,cidx])
print ridx, cidx
# Out:
# 6 0

# %%
print 'CV Best Parameters are, purity={}, nexamp={}, mean accuracy={}'.format(purity[ridx],nexamp[cidx],params[ridx,cidx])
# Out:
# CV Best Parameters are, purity=0.91, nexamp=5.0, mean accuracy=0.951388888889

# %%
print purity[ridx],nexamp[cidx]
dt=DecisionTree(purity[ridx],nexamp[cidx])
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 0.91 5.0
# 41
# Accuracy =  0.911111111111

# %%
print dt.find_depth()
# Out:
# 3

# %%
print dt
# Out:
#         C(class=Iris-virginica,Purity=0.944444444444)
#     I(Fidx=2,Score=0.17479482707,Split=4.75)
#         C(class=Iris-versicolor,Purity=0.970588235294)
# I(Fidx=2,Score=0.466541371531,Split=2.45)
#     C(class=Iris-setosa,Purity=1.0)
